# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import fbprophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
data = pd.read_csv("GOOG.csv.txt")
data.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2019-08-09  1197.989990  1203.880005  1183.603027  1188.010010
# 1  2019-08-12  1179.209961  1184.959961  1167.671997  1174.709961
# 2  2019-08-13  1171.459961  1204.780029  1171.459961  1197.270020
# 3  2019-08-14  1176.310059  1182.300049  1160.540039  1164.290039
# 4  2019-08-15  1163.500000  1175.839966  1162.109985  1167.260010
#
#      Adj Close   Volume
# 0  1188.010010  1065700
# 1  1174.709961  1003000
# 2  1197.270020  1294400
# 3  1164.290039  1578700
# 4  1167.260010  1218700

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(16,8))
plt.title("Google Closing Stock Price")
plt.plot(data["Close"])
plt.xlabel("Date", fontsize=18)
plt.ylabel("Close Price USD ($)", fontsize=18)
plt.show()

# %%
data = data[["Date","Close"]] 
data = data.rename(columns = {"Date":"ds","Close":"y"})
data.head()
# Out:
#            ds            y
# 0  2019-08-09  1188.010010
# 1  2019-08-12  1174.709961
# 2  2019-08-13  1197.270020
# 3  2019-08-14  1164.290039
# 4  2019-08-15  1167.260010

# %%
from fbprophet import Prophet
m = Prophet(daily_seasonality=True)
m.fit(data)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 4 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=365)
predictions=m.predict(future)
m.plot(predictions)
plt.title("Prediction of GOOGLE Stock Price")
plt.xlabel("Date")
plt.ylabel("Closing Stock Price")
plt.show()

# %%
m.plot_components(predictions)
plt.show()

# %%
data1 = pd.read_csv("^IXIC.csv")
data1.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2019-12-06  8634.250000  8665.440430  8630.580078  8656.530273
# 1  2019-12-09  8650.860352  8678.849609  8619.769531  8621.830078
# 2  2019-12-10  8623.559570  8650.759766  8600.820313  8616.179688
# 3  2019-12-11  8631.120117  8658.480469  8622.360352  8654.049805
# 4  2019-12-12  8645.360352  8745.820313  8633.599609  8717.320313
#
#      Adj Close      Volume
# 0  8656.530273  2053530000
# 1  8621.830078  2088520000
# 2  8616.179688  2053390000
# 3  8654.049805  1937850000
# 4  8717.320313  2388270000

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(16,8))
plt.title("Nasdaq Closing Stock Price")
plt.plot(data1["Close"])
plt.xlabel("Date", fontsize=18)
plt.ylabel("Close Price USD ($)", fontsize=18)
plt.show()

# %%
data1 = data1[["Date","Close"]] 
data1 = data1.rename(columns = {"Date":"ds","Close":"y"})
data1.head()
# Out:
#            ds            y
# 0  2019-12-06  8656.530273
# 1  2019-12-09  8621.830078
# 2  2019-12-10  8616.179688
# 3  2019-12-11  8654.049805
# 4  2019-12-12  8717.320313

# %%
m = Prophet(daily_seasonality=True)
m.fit(data1)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %%
future = m.make_future_dataframe(periods=65)
predictions=m.predict(future)
m.plot(predictions)
plt.title("Prediction of Nasdaq Stock Price")
plt.xlabel("Date")
plt.ylabel("Closing Stock Price")
plt.show()

# %%
m.plot_components(predictions)
plt.show()

# %%
data2 = pd.read_csv("TSLA.csv")
data2.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2019-12-06  67.000000  67.772003  66.954002  67.178001  67.178001  38062000
# 1  2019-12-09  67.318001  68.889999  67.015999  67.905998  67.905998  45115500
# 2  2019-12-10  67.991997  70.146004  67.862000  69.767998  69.767998  44141500
# 3  2019-12-11  70.375999  71.438004  70.218002  70.540001  70.540001  34489000
# 4  2019-12-12  70.984001  72.547997  70.646004  71.935997  71.935997  38819500

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(16,8))
plt.title("BITCOIN Closing Stock Price")
plt.plot(data2["Close"])
plt.xlabel("Date", fontsize=18)
plt.ylabel("Close Price USD ($)", fontsize=18)
plt.show()

# %%
data2 = data2[["Date","Close"]] 
data2 = data2.rename(columns = {"Date":"ds","Close":"y"})
data2.head()
# Out:
#            ds          y
# 0  2019-12-06  67.178001
# 1  2019-12-09  67.905998
# 2  2019-12-10  69.767998
# 3  2019-12-11  70.540001
# 4  2019-12-12  71.935997

# %%
from fbprophet import Prop
m = Prophet(daily_seasonality=True)
m.fit(data2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-60b30497be29> in <module>
# ----> 1 m = Prophet(daily_seasonality=True)
#       2 m.fit(data2)
#
# NameError: name 'Prophet' is not defined

# %%
future = m.make_future_dataframe(periods=365)
predictions=m.predict(future)
m.plot(predictions)
plt.title("Prediction of BITCOIN Stock Price")
plt.xlabel("Date")
plt.ylabel("Closing Stock Price")

from datetime import date,timedelta
start = date(2020,1,1)
end=date(2021,9,1)
plt.xlim(start,end) 
plt.show()

# %%
m.plot_components(predictions)
plt.show()
